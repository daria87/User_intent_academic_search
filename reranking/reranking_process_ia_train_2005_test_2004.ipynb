# %%
import numpy as np
import pandas as pd

# %%
import pickle

def read_pickle(file):
    f = open(file, 'rb')
    l_d = pickle.load(f)
    return l_d

# %%
df_q_proc = pd.read_csv("/content/drive/MyDrive/data_colab/inex_data/query_proc2005_agr.tsv", sep='\t')
df_q_proc
# Out:
#     qid                                              query intent_fin
# 0   203                          code signing verification    process
# 1   209  mining frequent pattern itemset sequence graph...    process
# 2   212                 hmm hidden markov model equation\n    process
# 3   218       computer assisted composing music notes midi    process
# 4   221  capabilities limitations commercial speech rec...    process
# 5   241                               single sign on  ldap    process
# 6   242                     web personalization approaches    process
# 7   248                                         clustering    process
# 8   249                                         clustering    process
# 9   253  evaluation usability experiment digital librar...    process
# 10  254  evaluation usability experiment digital libraries    process
# 11  255  evaluation methodology measures usability testing    process
# 12  257         free public licenses gnu linux open source    process
# 13  266                              thread implementation    process
# 14  271                                       watermarking    process
# 15  272                                     embedding data    process
# 16  275                      data mining frequent itemsets    process
# 17  284             thread implementation operating system    process
# 18  285                                   operating system    process

# %%
df_rel_proc_2005 = pd.read_csv("/content/drive/MyDrive/data_colab/inex_data/rel_proc2005_agr.tsv", sep='\t')
df_rel_proc_2005
# Out:
#                docid  qid                                        docno  \
# 0      ic/1998/w6026  203       ic/1998/w6026/article[1]/bdy[1]/sec[4]
# 1      ic/1998/w6026  203              ic/1998/w6026/article[1]/bdy[1]
# 2      ic/1998/w6026  203                     ic/1998/w6026/article[1]
# 3      ic/1998/w6026  203  ic/1998/w6026/article[1]/bdy[1]/sec[4]/p[2]
# 4      ic/1998/w6026  203  ic/1998/w6026/article[1]/bdy[1]/sec[4]/p[6]
# ...              ...  ...                                          ...
# 13265  co/2002/r1033  285              co/2002/r1033/article[1]/bdy[1]
# 13266  co/2002/r1033  285                     co/2002/r1033/article[1]
# 13267  co/2002/r6025  285       co/2002/r6025/article[1]/bdy[1]/sec[1]
# 13268  co/2002/r6025  285              co/2002/r6025/article[1]/bdy[1]
# 13269  co/2002/r6025  285                     co/2002/r6025/article[1]
#
#            tag  exhaustivity  specificity  gen_q  strict_q intent_fin
# 0          sec             1         0.55   0.55         0    process
# 1          bdy             1         0.14   0.14         0    process
# 2      article             1         0.10   0.10         0    process
# 3            p             1         1.00   1.00         0    process
# 4            p             1         1.00   1.00         0    process
# ...        ...           ...          ...    ...       ...        ...
# 13265      bdy             1         0.02   0.02         0    process
# 13266  article             1         0.02   0.02         0    process
# 13267      sec             1         0.25   0.25         0    process
# 13268      bdy             1         0.10   0.10         0    process
# 13269  article             1         0.08   0.08         0    process
#
# [13270 rows x 9 columns]

# %%
df_rel_proc_2004 = pd.read_csv("/content/drive/MyDrive/data_colab/inex_data/rel_proc2004_agr.tsv", sep='\t')
df_rel_proc_2004
# Out:
#                docid  qid                                              docno  \
# 0      cg/1995/g1062  130                           cg/1995/g1062/article[1]
# 1      cg/1995/g1062  130                    cg/1995/g1062/article[1]/bdy[1]
# 2      cg/1995/g1062  130             cg/1995/g1062/article[1]/bdy[1]/sec[1]
# 3      cg/1995/g1062  130        cg/1995/g1062/article[1]/bdy[1]/sec[1]/p[3]
# 4      cg/1995/g1062  130             cg/1995/g1062/article[1]/bdy[1]/sec[2]
# ...              ...  ...                                                ...
# 20966  tp/1996/i0831  200                     tp/1996/i0831/article[1]/bm[1]
# 20967  tp/1996/i0831  200              tp/1996/i0831/article[1]/bm[1]/bib[1]
# 20968  tp/1996/i0831  200      tp/1996/i0831/article[1]/bm[1]/bib[1]/bibl[1]
# 20969  tp/1996/i0831  200  tp/1996/i0831/article[1]/bm[1]/bib[1]/bibl[1]/...
# 20970  tp/1996/i0831  200  tp/1996/i0831/article[1]/bm[1]/bib[1]/bibl[1]/...
#
#            tag  exhaustivity  specificity  gen_q  sog_q  strict_q intent_fin
# 0      article             1            1   0.25   0.10         0    process
# 1          bdy             1            1   0.25   0.10         0    process
# 2          sec             1            1   0.25   0.10         0    process
# 3            p             1            1   0.25   0.10         0    process
# 4          sec             1            1   0.25   0.10         0    process
# ...        ...           ...          ...    ...    ...       ...        ...
# 20966       bm             1            1   0.25   0.10         0    process
# 20967      bib             1            1   0.25   0.10         0    process
# 20968     bibl             1            1   0.25   0.10         0    process
# 20969       bb             1            3   0.50   0.75         0    process
# 20970       ti             1            3   0.50   0.75         0    process
#
# [20971 rows x 10 columns]

# %%
df_rel_proc_2004 = df_rel_proc_2004[['qid','docno','sog_q']]
df_rel_proc_2004 = df_rel_proc_2004.rename(columns={'sog_q': 'label'})
df_rel_proc_2005 = df_rel_proc_2005.rename(columns={'gen_q': 'label'})
df_rel_proc_2005["qid"] = df_rel_proc_2005["qid"].astype(str)
df_rel_proc_2004["qid"] = df_rel_proc_2004["qid"].astype(str)

# %%
import numpy as np

def dcg_at_k(relevance_scores, k):
    """Calculate DCG for the given list of relevance scores up to position k."""
    relevance_scores = np.asfarray(relevance_scores)[:k]
    if relevance_scores.size:
        return np.sum(relevance_scores / np.log2(np.arange(2, relevance_scores.size + 2)))
    return 0

def ndcg_at_k(predicted_scores, ideal_scores, k):
    """Calculate NDCG for the given list of predicted and ideal relevance scores up to position k."""
    idcg = dcg_at_k(sorted(ideal_scores, reverse=True), k)
    if idcg == 0:
        return 0
    dcg = dcg_at_k(predicted_scores, k)
    return dcg / idcg

# %%
def ndcg_apply(df,k):
  grouped_result = df.groupby('qid')["label"].agg(list)
  l_ndcg = []
  for predicted_scores in grouped_result.to_list():
    ideal_scores = sorted(predicted_scores, reverse=True)
    ndcg_score = ndcg_at_k(predicted_scores, ideal_scores,k)
    #print(f"NDCG at 10: {ndcg_score:.4f}")
    l_ndcg.append(ndcg_score)
  return l_ndcg

# %% [markdown]
# BM25

# %%
bm25_res = pd.read_csv('/content/drive/MyDrive/data_colab/inex_data/res_with_features_proc_2004_features_and_sections.tsv', sep='\t')
bm25_res["qid"] = bm25_res["qid"].astype(str)

# %%
bm25_res = bm25_res.merge(df_rel_proc_2004[['qid', 'docno', 'label']], on=['qid', 'docno'], how='left')
bm25_res['label'] = bm25_res['label'].fillna(0)
bm25_res.head()
# Out:
#    Unnamed: 0  qid  docid                                   docno  rank  \
# 0           0  130   3286  mu/1997/u3024/article[1]/bdy[1]/sec[3]     0
# 1           1  130  44112  td/2001/l1236/article[1]/bdy[1]/sec[7]     1
# 2           2  130  36557  tk/1996/k0285/article[1]/bdy[1]/sec[6]     2
# 3           3  130  35760  tk/1999/k0748/article[1]/bdy[1]/sec[7]     3
# 4           4  130  65236  ts/2001/e1111/article[1]/bdy[1]/sec[1]     4
#
#    score_bm25                               query intent_fin  score_tfidf  \
# 0   19.156431  object database version management    process    12.491302
# 1   18.206757  object database version management    process    11.914260
# 2   18.096122  object database version management    process    11.857269
# 3   17.873296  object database version management    process    11.708314
# 4   16.929100  object database version management    process    11.057341
#
#                                                 text  ...  max_tfidf  \
# 0  Purpose multimedia DBMS multimedia database ma...  ...  12.491302
# 1  DOK Project DOK system partially implemented. ...  ...  12.491302
# 2  CONCLUSION First, paper, described prototype O...  ...  12.491302
# 3  Future Works current version, treat OODB stora...  ...  12.491302
# 4  Introduction Software configuration management...  ...  12.491302
#
#    mean_tfidf  var_tfidf  document_length  contains_methodology  \
# 0    7.459717   1.016502              402                     0
# 1    7.459717   1.016502              645                     0
# 2    7.459717   1.016502              588                     0
# 3    7.459717   1.016502               99                     0
# 4    7.459717   1.016502              454                     0
#
#    tfidf_cosine_similarity  bert_cosine_similarity  query_in_text  \
# 0                 0.231780                0.535138              0
# 1                 0.255127                0.333425              0
# 2                 0.122244                0.495080              0
# 3                 0.296808                0.575354              0
# 4                 0.352588                0.534704              0
#
#    query_in_methodology  label
# 0                     0   0.25
# 1                     0   0.00
# 2                     0   0.50
# 3                     0   0.25
# 4                     0   0.50
#
# [5 rows x 22 columns]

# %%
mean_bm25 = np.mean(ndcg_apply(bm25_res,20))
print("NDCG@20 BM25", mean_bm25)
# Out:
# NDCG@20 BM25 0.3671774519748427

# %% [markdown]
# 1. INTENT-AGNOSTIC

# %%
train_data = pd.read_csv('/content/drive/MyDrive/data_colab/inex_data/res_with_features_proc_2005_features_and_sections.tsv', sep='\t')
train_data["qid"] = train_data["qid"].astype(str)

# %%
train_data = train_data.merge(df_rel_proc_2005[['qid', 'docno', 'label']], on=['qid', 'docno'], how='left')
train_data['label'] = train_data['label'].fillna(0)
train_data.head()
# Out:
#    qid  docid                                   docno  rank  score_bm25  \
# 0  203  23601  co/2000/r7108/article[1]/bdy[1]/sec[2]     0   22.160864
# 1  203  11887  dt/2001/d4006/article[1]/bdy[1]/sec[3]     1   21.497232
# 2  203  11888  dt/2001/d4006/article[1]/bdy[1]/sec[4]     2   21.165475
# 3  203  24890  co/1997/r6076/article[1]/bdy[1]/sec[4]     3   20.580498
# 4  203  25503  co/1997/r6026/article[1]/bdy[1]/sec[6]     4   20.172168
#
#                        query intent_fin  score_tfidf  \
# 0  code signing verification    process    12.755553
# 1  code signing verification    process    12.350038
# 2  code signing verification    process    12.153532
# 3  code signing verification    process    11.867551
# 4  code signing verification    process    11.672510
#
#                                                 text   sum_tfidf  ...  \
# 0  CODE SIGNING VERIFICATION Typically, software ...  8285.84893  ...
# 1  RTL STATIC SIGN-OFF ISSUES Using concepts fram...  8285.84893  ...
# 2  EFFECTIVE EQUIVALENCE-CHECKING METHODOLOGY Tod...  8285.84893  ...
# 3  CONCLUSION general-purpose secure code distrib...  8285.84893  ...
# 4  Secure Code Distribution, pp. 76-79 X. Nick Zh...  8285.84893  ...
#
#    max_tfidf  mean_tfidf  var_tfidf  document_length  query_in_text  \
# 0  12.755553    5.843335    1.35043              199              1
# 1  12.755553    5.843335    1.35043              491              0
# 2  12.755553    5.843335    1.35043              579              0
# 3  12.755553    5.843335    1.35043              151              0
# 4  12.755553    5.843335    1.35043              108              0
#
#    contains_methodology  query_in_methodology  tfidf_cosine_similarity  \
# 0                     0                     0                 0.153413
# 1                     1                     0                 0.042411
# 2                     1                     0                 0.087823
# 3                     0                     0                 0.092146
# 4                     0                     0                 0.136160
#
#    bert_cosine_similarity  label
# 0                0.515524   1.00
# 1                0.379981   0.00
# 2                0.249259   0.00
# 3                0.419163   0.65
# 4                0.405383   0.96
#
# [5 rows x 21 columns]

# %%
test_data = pd.read_csv('/content/drive/MyDrive/data_colab/inex_data/res_with_features_proc_2004_features_and_sections.tsv',sep = '\t')
test_data["qid"] = test_data["qid"].astype(str)

# %%
test_data = test_data.merge(df_rel_proc_2004[['qid', 'docno', 'label']], on=['qid', 'docno'], how='left')
test_data['label'] = test_data['label'].fillna(0)
test_data.head()
# Out:
#    Unnamed: 0  qid  docid                                   docno  rank  \
# 0           0  130   3286  mu/1997/u3024/article[1]/bdy[1]/sec[3]     0
# 1           1  130  44112  td/2001/l1236/article[1]/bdy[1]/sec[7]     1
# 2           2  130  36557  tk/1996/k0285/article[1]/bdy[1]/sec[6]     2
# 3           3  130  35760  tk/1999/k0748/article[1]/bdy[1]/sec[7]     3
# 4           4  130  65236  ts/2001/e1111/article[1]/bdy[1]/sec[1]     4
#
#    score_bm25                               query intent_fin  score_tfidf  \
# 0   19.156431  object database version management    process    12.491302
# 1   18.206757  object database version management    process    11.914260
# 2   18.096122  object database version management    process    11.857269
# 3   17.873296  object database version management    process    11.708314
# 4   16.929100  object database version management    process    11.057341
#
#                                                 text  ...  max_tfidf  \
# 0  Purpose multimedia DBMS multimedia database ma...  ...  12.491302
# 1  DOK Project DOK system partially implemented. ...  ...  12.491302
# 2  CONCLUSION First, paper, described prototype O...  ...  12.491302
# 3  Future Works current version, treat OODB stora...  ...  12.491302
# 4  Introduction Software configuration management...  ...  12.491302
#
#    mean_tfidf  var_tfidf  document_length  contains_methodology  \
# 0    7.459717   1.016502              402                     0
# 1    7.459717   1.016502              645                     0
# 2    7.459717   1.016502              588                     0
# 3    7.459717   1.016502               99                     0
# 4    7.459717   1.016502              454                     0
#
#    tfidf_cosine_similarity  bert_cosine_similarity  query_in_text  \
# 0                 0.231780                0.535138              0
# 1                 0.255127                0.333425              0
# 2                 0.122244                0.495080              0
# 3                 0.296808                0.575354              0
# 4                 0.352588                0.534704              0
#
#    query_in_methodology  label
# 0                     0   0.25
# 1                     0   0.00
# 2                     0   0.50
# 3                     0   0.25
# 4                     0   0.50
#
# [5 rows x 22 columns]

# %%
relevance_labels = np.array(train_data['label'].to_list())

# Define the number of bins for label mapping (0 to 6 corresponds to 7 gains)
n_bins = 7

# Use numpy to digitize the labels into bins
int_labels = np.digitize(relevance_labels, np.linspace(min(relevance_labels), max(relevance_labels), n_bins))
print(int_labels[10:])

# Adjust to ensure labels are within 0 to 6
int_labels = int_labels - 1 # Digitize returns 1-indexed bins, so subtract 1

label_gain = sorted(set(int_labels))
print(label_gain)
# Out:
# [1 1 1 ... 1 1 1]
# [0, 1, 2, 3, 4, 5, 6]

# %%
relevance_labels_test = test_data['label'].to_list(
)
# Remove duplicates by converting the list to a set, then convert back to a sorted list
label_gain_test = sorted(set(relevance_labels_test))
print(label_gain_test)

int_labels_test = [label_gain_test.index(label) for label in relevance_labels_test]
# Out:
# [0.0, 0.1, 0.25, 0.5, 0.75, 0.9, 1.0]

# %%
import numpy as np

def dcg_at_k(relevance_scores, k):
    """Calculate DCG for the given list of relevance scores up to position k."""
    relevance_scores = np.asfarray(relevance_scores)[:k]
    if relevance_scores.size:
        return np.sum(relevance_scores / np.log2(np.arange(2, relevance_scores.size + 2)))
    return 0

def ndcg_at_k(predicted_scores, ideal_scores, k):
    """Calculate NDCG for the given list of predicted and ideal relevance scores up to position k."""
    idcg = dcg_at_k(sorted(ideal_scores, reverse=True), k)
    if idcg == 0:
        return 0
    dcg = dcg_at_k(predicted_scores, k)
    return dcg / idcg

# %%
def ndcg_apply(df,k):
  grouped_result = df.groupby('qid')["label"].agg(list)
  l_ndcg = []
  for predicted_scores in grouped_result.to_list():
    ideal_scores = sorted(predicted_scores, reverse=True)
    ndcg_score = ndcg_at_k(predicted_scores, ideal_scores,k)
    #print(f"NDCG at 10: {ndcg_score:.4f}")
    l_ndcg.append(ndcg_score)
  return l_ndcg

# %%
# !pip install pandas lightgbm
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.2.2)
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.10/dist-packages (4.5.0)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from lightgbm) (1.13.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import lightgbm as lgb

# %%
#Prepare the features (X) and labels (y)

X_train_na = train_data[['score_bm25','score_tfidf','sum_tfidf','mean_tfidf','min_tfidf','max_tfidf','var_tfidf','document_length','query_in_text']].values  # Including the user intent feature
y_train_na = train_data['label'].values  # Use the scaled labels
print(len(X_train_na))

# Extract the group sizes (number of documents per query) for training
group_train_na = train_data.groupby('qid').size().to_numpy()

# Create the LightGBM dataset
train_data_na = lgb.Dataset(X_train_na, label=int_labels, group=group_train_na)
print(len(X_train_na))
print(len(relevance_labels))
l_tfidf = train_data['var_tfidf'].to_list()
# Out:
# 23623
# 23623
# 23623

# %%
# Prepare the features (X) and labels (y) for test data
X_test_na = test_data[['score_bm25','score_tfidf','sum_tfidf','mean_tfidf','min_tfidf','max_tfidf','var_tfidf','document_length','query_in_text']].values
y_test_na = test_data['label'].values  # Use the actual labels

# Extract the group sizes (number of documents per query) for test data
group_test_na = test_data.groupby('qid').size().to_numpy()

# Create LightGBM dataset for test set
test_data_na = lgb.Dataset(X_test_na, label=int_labels_test, group=group_test_na)

# %%
#min_data_in_leaf previousely 50, num leaves 16 max depth 6

params_lm = {
    'objective': 'lambdarank',
    'metric': 'ndcg',
    'boosting': 'gbdt',
    'num_leaves': 16,
    'max_depth': 6,
    'learning_rate': 0.01,
    'feature_fraction': 0.9,
    'min_data_in_leaf': 100,  # Increase this to regularize more
    'label_gain': label_gain,  # Increase this to regularize more
    'lambda_l1': 0.1,  # Add L1 regularization
    'lambda_l2': 0.1,  # Add L2 regularization
    'verbose': -1
}

# %%
import matplotlib.pyplot as plt

#Initialize dictionaries to store results
evals_result = {'train': [], 'test': []}

# Custom callback to track evaluation results manually and print every 10 rounds
def record_evaluation(env):
    results = env.evaluation_result_list
    train_ndcg = results[0][2]  # Training NDCG (assuming first is train)
    test_ndcg = results[1][2]   # Test NDCG (assuming second is test)

    # Append to the evals_result dict
    evals_result['train'].append(train_ndcg)
    evals_result['test'].append(test_ndcg)

    # Print every 10 rounds
    if (env.iteration + 1) % 10 == 0:
        print(f"Round {env.iteration + 1}: Train NDCG = {train_ndcg}, Test NDCG = {test_ndcg}")

# Train the model and track NDCG on training and test sets
ranker_lm_na = lgb.train(
    params_lm,
    train_data_na,
    num_boost_round=150,
    valid_sets=[train_data_na, test_data_na],  # Include both training and test sets for evaluation
    valid_names=['train', 'test'],  # Give names to the datasets
    callbacks=[record_evaluation, lgb.early_stopping(stopping_rounds=30)]
)
# Out:
# Training until validation scores don't improve for 30 rounds
# Round 10: Train NDCG = 0.5508771929824561, Test NDCG = 0.5144860033441625
# Round 20: Train NDCG = 0.5508771929824561, Test NDCG = 0.4988266314977886
# Round 30: Train NDCG = 0.5508771929824561, Test NDCG = 0.5144098899696763
# Early stopping, best iteration is:
# [8]	train's ndcg@1: 0.550877	train's ndcg@2: 0.514486	train's ndcg@3: 0.50638	train's ndcg@4: 0.503076	train's ndcg@5: 0.484907	test's ndcg@1: 0.570833	test's ndcg@2: 0.505029	test's ndcg@3: 0.486494	test's ndcg@4: 0.469355	test's ndcg@5: 0.479094

# %%
def apply_lambdamart_na(df, model):
    ranked_results = []
    queries = df['qid'].unique()
    for qid in queries:
        subset = df[df['qid'] == qid]
        features = subset[['score_bm25','score_tfidf','sum_tfidf','mean_tfidf','min_tfidf','max_tfidf','var_tfidf','document_length','query_in_text']].values
        scores = model.predict(features)
        subset = subset.assign(lambdamart_score=scores)
        ranked_results.append(subset.sort_values(by='lambdamart_score', ascending=False))

    return pd.concat(ranked_results)

# %%
result_lm_na = apply_lambdamart_na(test_data, ranker_lm_na)

# %%
result_lm_na = result_lm_na.reset_index(drop=True)
result_lm_na["qid"] = result_lm_na["qid"].astype(str)

# %% [markdown]
# 2.INTENT-AWARE

# %%
# Prepare the features (X) and labels (y)
X_train_ia = train_data[['score_bm25','score_tfidf','sum_tfidf','mean_tfidf','min_tfidf','max_tfidf','var_tfidf','document_length','query_in_text','contains_methodology','query_in_methodology','bert_cosine_similarity','tfidf_cosine_similarity']].values
y_train_ia = train_data['label'].values  # Use the scaled labels
print(len(X_train_ia))

# Extract the group sizes (number of documents per query) for training
group_train_ia = train_data.groupby('qid').size().to_numpy()

# Create the LightGBM dataset
train_data_ia = lgb.Dataset(X_train_ia, label=int_labels, group=group_train_ia)
print(len(X_train_ia))
print(len(relevance_labels))
# Out:
# 23623
# 23623
# 23623

# %%
# Prepare the features (X) and labels (y) for test data
X_test_ia = test_data[['score_bm25','score_tfidf','sum_tfidf','mean_tfidf','min_tfidf','max_tfidf','var_tfidf','document_length','query_in_text','contains_methodology','query_in_methodology','bert_cosine_similarity','tfidf_cosine_similarity']].values
y_test_ia = test_data['label'].values  # Use the actual labels

# Extract the group sizes (number of documents per query) for test data
group_test_ia = test_data.groupby('qid').size().to_numpy()

# Create LightGBM dataset for test set
test_data_ia = lgb.Dataset(X_test_ia, label=int_labels_test, group=group_test_ia)
print(len(X_test_ia))
print(len(relevance_labels_test))
# Out:
# 38880
# 38880

# %%
import lightgbm as lgb
import matplotlib.pyplot as plt

# Initialize dictionaries to store NDCG results
evals_result = {'train': [], 'test': []}

# Custom callback to track evaluation results manually and print every 10 rounds
def record_evaluation(env):
    results = env.evaluation_result_list
    train_ndcg = results[0][2]  # Training NDCG (assuming first is train)
    test_ndcg = results[1][2]   # Test NDCG (assuming second is test)

    # Append to the evals_result dict
    evals_result['train'].append(train_ndcg)
    evals_result['test'].append(test_ndcg)


# Train the model with early stopping using callbacks
ranker_lm_ia = lgb.train(
    params_lm,
    train_data_ia,
    num_boost_round=150,  # Set maximum number of boosting rounds
    valid_sets=[train_data_ia, test_data_ia],  # Include both training and test sets for evaluation
    valid_names=['train', 'test'],
    callbacks=[record_evaluation, lgb.early_stopping(stopping_rounds=15)]  # Early stopping after 10 rounds without improvement
)
# Out:
# Training until validation scores don't improve for 15 rounds
# Early stopping, best iteration is:
# [13]	train's ndcg@1: 0.521053	train's ndcg@2: 0.496667	train's ndcg@3: 0.514943	train's ndcg@4: 0.536771	train's ndcg@5: 0.539695	test's ndcg@1: 0.59881	test's ndcg@2: 0.501273	test's ndcg@3: 0.489792	test's ndcg@4: 0.494356	test's ndcg@5: 0.495787

# %%
def apply_lambdamart_ia(df, model):
    ranked_results = []
    queries = df['qid'].unique()
    for qid in queries:
        subset = df[df['qid'] == qid]
        features = subset[['score_bm25','score_tfidf','sum_tfidf','mean_tfidf','min_tfidf','max_tfidf','var_tfidf','document_length','query_in_text','contains_methodology','query_in_methodology','bert_cosine_similarity','tfidf_cosine_similarity']].values
        scores = model.predict(features)
        subset = subset.assign(lambdamart_score=scores)
        ranked_results.append(subset.sort_values(by='lambdamart_score', ascending=False))

    return pd.concat(ranked_results)

# %%
result_lm_ia = apply_lambdamart_ia(test_data, ranker_lm_ia)
result_lm_ia = result_lm_ia.reset_index(drop=True)
result_lm_ia["qid"] = result_lm_ia["qid"].astype(str)

# %%
mean_bm25 = round(np.mean(ndcg_apply(bm25_res,20)),4)
print("NDCG@100 BM25:", mean_bm25)
mean_sr_na = round(np.mean(ndcg_apply(result_lm_na,20)),4)
print("NDCG@100 lambdamart non intent aware:", mean_sr_na)
mean_sr_ia = round(np.mean(ndcg_apply(result_lm_ia,20)),4)
print("NDCG@100 lambdamart intent aware:", mean_sr_ia)
# Out:
# NDCG@100 BM25: 0.3672
# NDCG@100 lambdamart non intent aware: 0.3915
# NDCG@100 lambdamart intent aware: 0.4714

# %%
improv = (np.mean(ndcg_apply(result_lm_na,20)) - np.mean(ndcg_apply(bm25_res,20)))/np.mean(ndcg_apply(bm25_res,20))*100
print(f"improvement na is {round(improv,2)} percent")
# Out:
# improvement na is 6.62 percent

# %%
improv = (np.mean(ndcg_apply(result_lm_ia,20)) - np.mean(ndcg_apply(bm25_res,20)))/np.mean(ndcg_apply(bm25_res,20))*100
print(f"improvement ia is {round(improv,2)} percent")
# Out:
# improvement ia is 28.38 percent

# %%
#Prepare the features (X) and labels (y)

X_train_sr_na = train_data[['score_bm25','score_tfidf','sum_tfidf','mean_tfidf','min_tfidf','max_tfidf','var_tfidf','document_length','query_in_text']].values  # Including the user intent feature
y_train_sr_na = train_data['label'].values  # Use the scaled labels
print(len(X_train_sr_na))

# Extract the group sizes (number of documents per query) for training
group_train_sr_na = train_data.groupby('qid').size().to_numpy()

# Create the LightGBM dataset
train_data_sr_na = lgb.Dataset(X_train_sr_na, label=int_labels, group=group_train_sr_na)
print(len(X_train_sr_na))
print(len(relevance_labels))
# Out:
# 23623
# 23623
# 23623

# %%
# Prepare the features (X) and labels (y) for test data
X_test_sr_na = test_data[['score_bm25','score_tfidf','sum_tfidf','mean_tfidf','min_tfidf','max_tfidf','var_tfidf','document_length','query_in_text']].values
y_test_sr_na = test_data['label'].values  # Use the actual labels

# Extract the group sizes (number of documents per query) for test data
group_test_sr_na = test_data.groupby('qid').size().to_numpy()

# Create LightGBM dataset for test set
test_data_sr_na = lgb.Dataset(X_test_sr_na, label=int_labels_test, group=group_test_sr_na)

# %%
# Define the parameters for Soft rank
params_sr = {
    'objective': 'lambdarank',
    'metric': 'ndcg',
    'boosting': 'gbdt',
    'num_leaves': 31,
    'learning_rate': 0.01,
    'feature_fraction': 0.9,
    'label_gain': label_gain,  # Adjust this to cover the range of your scaled labels
    'verbose': -1
}

# %%
import matplotlib.pyplot as plt


#Initialize dictionaries to store results
evals_result = {'train': [], 'test': []}

# Custom callback to track evaluation results manually and print every 10 rounds
def record_evaluation(env):
    results = env.evaluation_result_list
    train_ndcg = results[0][2]  # Training NDCG (assuming first is train)
    test_ndcg = results[1][2]   # Test NDCG (assuming second is test)

    # Append to the evals_result dict
    evals_result['train'].append(train_ndcg)
    evals_result['test'].append(test_ndcg)

    # Print every 10 rounds
    if (env.iteration + 1) % 10 == 0:
        print(f"Round {env.iteration + 1}: Train NDCG = {train_ndcg}, Test NDCG = {test_ndcg}")

# Train the model and track NDCG on training and test sets
ranker_sr_na = lgb.train(
    params_sr,
    train_data_sr_na,
    num_boost_round=150,
    valid_sets=[train_data_sr_na, test_data_sr_na],  # Include both training and test sets for evaluation
    valid_names=['train', 'test'],  # Give names to the datasets
    callbacks=[record_evaluation, lgb.early_stopping(stopping_rounds=20)]
)
# Out:
# Training until validation scores don't improve for 20 rounds
# Round 10: Train NDCG = 0.6719298245614035, Test NDCG = 0.5958846956417774
# Round 20: Train NDCG = 0.6824561403508772, Test NDCG = 0.6057093922104532
# Early stopping, best iteration is:
# [4]	train's ndcg@1: 0.545614	train's ndcg@2: 0.492022	train's ndcg@3: 0.510271	train's ndcg@4: 0.491196	train's ndcg@5: 0.489828	test's ndcg@1: 0.444643	test's ndcg@2: 0.401004	test's ndcg@3: 0.374842	test's ndcg@4: 0.37122	test's ndcg@5: 0.37611

# %%
def apply_soft_rank_na(df):
  qid_list = df['qid'].unique()
  ranked_results = []
  for qid in qid_list:
      subset = df[df['qid'] == qid]
      features = subset[['score_bm25','score_tfidf','sum_tfidf','mean_tfidf','min_tfidf','max_tfidf','var_tfidf','document_length','query_in_text']].values  # Only numeric features for prediction
      scores = ranker_sr_na.predict(features)
      subset = subset.assign(soft_rank_score=scores)
      ranked_results.append(subset.sort_values(by='soft_rank_score', ascending=False))
  return pd.concat(ranked_results)

# Apply the AdaRank model to re-rank the documents
result_sr_na = apply_soft_rank_na(test_data)

# Reset index to get a clean DataFrame
result_sr_na = result_sr_na.reset_index(drop=True)

# %%
result_sr_na["qid"] = result_sr_na["qid"].astype(str)

# %%
# Prepare the features (X) and labels (y)
X_train_sr_ia = train_data[['score_bm25','score_tfidf','sum_tfidf','mean_tfidf','min_tfidf','max_tfidf','var_tfidf','document_length','query_in_text','contains_methodology','query_in_methodology','bert_cosine_similarity','tfidf_cosine_similarity']].values  # Including the user intent feature
y_train_sr_ia = train_data['label'].values  # Use the scaled labels
print(len(X_train_sr_ia))

# Extract the group sizes (number of documents per query) for training
group_train_sr_ia = train_data.groupby('qid').size().to_numpy()

# Create the LightGBM dataset
train_data_sr_ia = lgb.Dataset(X_train_sr_ia, label=int_labels, group=group_train_sr_ia)
print(len(X_train_sr_ia))
print(len(relevance_labels))
# Out:
# 23623
# 23623
# 23623

# %%
# Prepare the features (X) and labels (y) for test data
X_test_sr_ia = test_data[['score_bm25','score_tfidf','sum_tfidf','mean_tfidf','min_tfidf','max_tfidf','var_tfidf','document_length','query_in_text','contains_methodology','query_in_methodology','bert_cosine_similarity','tfidf_cosine_similarity']].values
y_test_sr_ia = test_data['label'].values  # Use the actual labels

# Extract the group sizes (number of documents per query) for test data
group_test_sr_ia = test_data.groupby('qid').size().to_numpy()

# Create LightGBM dataset for test set
test_data_sr_ia = lgb.Dataset(X_test_sr_ia, label=int_labels_test, group=group_test_sr_ia)
print(len(X_test_sr_ia))
print(len(relevance_labels_test))
# Out:
# 38880
# 38880

# %%
#Initialize dictionaries to store results
evals_result = {'train': [], 'test': []}

# Custom callback to track evaluation results manually and print every 10 rounds
def record_evaluation(env):
    results = env.evaluation_result_list
    train_ndcg = results[0][2]  # Training NDCG (assuming first is train)
    test_ndcg = results[1][2]   # Test NDCG (assuming second is test)

    # Append to the evals_result dict
    evals_result['train'].append(train_ndcg)
    evals_result['test'].append(test_ndcg)

    # Print every 10 rounds
    if (env.iteration + 1) % 10 == 0:
        print(f"Round {env.iteration + 1}: Train NDCG = {train_ndcg}, Test NDCG = {test_ndcg}")


# Train the model with early stopping using callbacks
ranker_sr_ia = lgb.train(
    params_sr,
    train_data_sr_ia,
    num_boost_round=150,  # Set maximum number of boosting rounds
    valid_sets=[train_data_sr_ia, test_data_sr_ia],  # Include both training and test sets for evaluation
    valid_names=['train', 'test'],
    callbacks=[record_evaluation, lgb.early_stopping(stopping_rounds=30)]  # Early stopping after 10 rounds without improvement
)
# Out:
# Training until validation scores don't improve for 30 rounds
# Round 10: Train NDCG = 0.7157894736842105, Test NDCG = 0.6504943761189464
# Round 20: Train NDCG = 0.7157894736842105, Test NDCG = 0.6722124284549208
# Round 30: Train NDCG = 0.7473684210526316, Test NDCG = 0.6967935414800492
# Round 40: Train NDCG = 0.7736842105263158, Test NDCG = 0.7265027766312294
# Round 50: Train NDCG = 0.7736842105263158, Test NDCG = 0.7332896679862213
# Round 60: Train NDCG = 0.7736842105263158, Test NDCG = 0.7536503420511973
# Early stopping, best iteration is:
# [33]	train's ndcg@1: 0.747368	train's ndcg@2: 0.696794	train's ndcg@3: 0.669554	train's ndcg@4: 0.65809	train's ndcg@5: 0.643647	test's ndcg@1: 0.533333	test's ndcg@2: 0.547029	test's ndcg@3: 0.536775	test's ndcg@4: 0.540103	test's ndcg@5: 0.538945

# %%
def apply_soft_rank_ia(df):
  qid_list = df['qid'].unique()
  ranked_results = []
  for qid in qid_list:
      subset = df[df['qid'] == qid]
      features = subset[['score_bm25','score_tfidf','sum_tfidf','mean_tfidf','min_tfidf','max_tfidf','var_tfidf','document_length','query_in_text','contains_methodology','query_in_methodology','bert_cosine_similarity','tfidf_cosine_similarity']].values  # Only numeric features for prediction
      scores = ranker_sr_ia.predict(features)
      subset = subset.assign(soft_rank_score=scores)
      ranked_results.append(subset.sort_values(by='soft_rank_score', ascending=False))
  return pd.concat(ranked_results)

# %%
result_sr_ia = apply_soft_rank_ia(test_data)
result_sr_ia = result_sr_ia.reset_index(drop=True)
result_sr_ia["qid"] = result_sr_ia["qid"].astype(str)

# %%
mean_bm25 = round(np.mean(ndcg_apply(bm25_res,20)),4)
print("NDCG@100 soft rank BM25:", mean_bm25)
mean_sr_na = round(np.mean(ndcg_apply(result_sr_na,20)),4)
print("NDCG@100 soft rank non intent aware:", mean_sr_na)
mean_sr_ia = round(np.mean(ndcg_apply(result_sr_ia,20)),4)
print("NDCG@100 soft rank intent aware:", mean_sr_ia)
# Out:
# NDCG@100 soft rank BM25: 0.3672
# NDCG@100 soft rank non intent aware: 0.3418
# NDCG@100 soft rank intent aware: 0.4711

# %%
improv = (np.mean(ndcg_apply(result_sr_na,20)) - np.mean(ndcg_apply(bm25_res,20)))/np.mean(ndcg_apply(bm25_res,20))*100
print(f"improvement na is {round(improv,2)} percent")
# Out:
# improvement na is -6.9 percent

# %%
improv = (np.mean(ndcg_apply(result_sr_ia,20)) - np.mean(ndcg_apply(bm25_res,20)))/np.mean(ndcg_apply(bm25_res,20))*100
print(f"improvement na is {round(improv,2)} percent")
# Out:
# improvement na is 28.3 percent

# %%
from scipy.stats import ttest_rel
nb_el = 20

baseline = ndcg_apply(bm25_res,nb_el)
ndcg_lm_na = ndcg_apply(result_lm_na,nb_el)
ndcg_lm_ia = ndcg_apply(result_lm_ia,nb_el)
ndcg_sr_na = ndcg_apply(result_sr_na,nb_el)
ndcg_sr_ia = ndcg_apply(result_sr_ia,nb_el)




# Perform t-tests
t_stat1, p_val1 = ttest_rel(baseline, ndcg_lm_na)
t_stat2, p_val2 = ttest_rel(baseline, ndcg_lm_ia)
t_stat3, p_val3 = ttest_rel(baseline, ndcg_sr_na)
t_stat4, p_val4 = ttest_rel(baseline, ndcg_sr_ia)

# Collect p-values
p_values = [p_val1, p_val2,p_val3,p_val4]
print(p_values)
# Out:
# [0.5503745324060962, 0.004458828155660332, 0.4649007834618375, 0.0011984679563899067]

# %%
# Number of tests
num_tests = len(p_values)
print(num_tests)

# Apply Bonferroni correction
bonferroni_corrected_pvals = [min(p * num_tests, 1.0) for p in p_values]
print(bonferroni_corrected_pvals)
# Out:
# 4
# [1.0, 0.017835312622641326, 1.0, 0.004793871825559627]

# %%
alpha = 0.05

# Apply Bonferroni correction
bonferroni_corrected_pvals = [min(p * num_tests, 1.0) for p in p_values]
l_names = ['Lambdamart na','Lambdamart_ia','Softrank_na','Softrank_ia']

# Check for significance and print results
for i, (t_stat, p_val, corrected_pval) in enumerate(zip([t_stat1,t_stat2,t_stat3,t_stat4], p_values, bonferroni_corrected_pvals)):
    is_significant = corrected_pval <= alpha
    significance_str = "Significant" if is_significant else "Not Significant"
    print(f"Result {i+1}:")
    print(l_names[i])
    print(f"  t-statistic = {t_stat:.4f}")
    print(f"  original p-value = {p_val:.4f}")
    print(f"  Bonferroni corrected p-value = {corrected_pval:.4f} ({significance_str})")
    print()
# Out:
# Result 1:
# Lambdamart na
#   t-statistic = -0.6048
#   original p-value = 0.5504
#   Bonferroni corrected p-value = 1.0000 (Not Significant)
#
# Result 2:
# Lambdamart_ia
#   t-statistic = -3.1028
#   original p-value = 0.0045
#   Bonferroni corrected p-value = 0.0178 (Significant)
#
# Result 3:
# Softrank_na
#   t-statistic = 0.7413
#   original p-value = 0.4649
#   Bonferroni corrected p-value = 1.0000 (Not Significant)
#
# Result 4:
# Softrank_ia
#   t-statistic = -3.6199
#   original p-value = 0.0012
#   Bonferroni corrected p-value = 0.0048 (Significant)
